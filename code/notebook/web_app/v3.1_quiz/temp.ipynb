# %%
from flask import Flask, render_template, request
import pandas as pd
import random

df = pd.read_csv(r'D:\Projects\Face_analysis_game\code\notebook\web_app\v3.1_quiz\static\test.csv')
# return df

# %%
df
# Out:
#                img_path ground_truth   img_size
# 0   /path/to/image1.jpg          cat   1024x768
# 1   /path/to/image2.jpg          dog    800x600
# 2   /path/to/image3.jpg       flower   1200x900
# 3   /path/to/image4.jpg         tree  1600x1200
# 4   /path/to/image5.jpg          car   1280x720
# 5   /path/to/image6.jpg       sunset  1920x1080
# 6   /path/to/image7.jpg        beach   1440x900
# 7   /path/to/image8.jpg     mountain  2000x1500
# 8   /path/to/image9.jpg     building   1024x768
# 9  /path/to/image10.jpg         bird    800x600

# %%
# shuffle the rows of df
df = df.sample(frac=1).reset_index(drop=True)

# %%
df
# Out:
#                img_path ground_truth   img_size
# 0   /path/to/image4.jpg         tree  1600x1200
# 1   /path/to/image3.jpg       flower   1200x900
# 2  /path/to/image10.jpg         bird    800x600
# 3   /path/to/image6.jpg       sunset  1920x1080
# 4   /path/to/image2.jpg          dog    800x600
# 5   /path/to/image5.jpg          car   1280x720
# 6   /path/to/image7.jpg        beach   1440x900
# 7   /path/to/image8.jpg     mountain  2000x1500
# 8   /path/to/image1.jpg          cat   1024x768
# 9   /path/to/image9.jpg     building   1024x768

# %%
generate_questions(df,3)
# Out:
# Generating questions...
# After Shuffling data...
# we get the incorrect choices None
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 generate_questions(df,3)
#
# Cell In[20], line 21, in generate_questions(data, num_questions)
#      19 # Create a list of options including the correct and incorrect image paths
#      20 options = [correct_img_path]
# ---> 21 options.extend([row['img_path'] for row in incorrect_choices])
#      23 # Shuffle the options to randomize their order
#      24 options = random.sample(options, len(options))
#
# TypeError: 'NoneType' object is not iterable

# %%
df.iloc[0]
# Out:
# img_path        /path/to/image4.jpg
# ground_truth                   tree
# img_size                  1600x1200
# Name: 0, dtype: object

# %%
# from flask import Flask, render_template, request
import pandas as pd
import random

df = pd.read_csv(r'D:\Projects\Face_analysis_game\code\notebook\web_app\v3.1_quiz\static\test.csv')
# return df

def generate_questions(data, num_questions):
    print('Generating questions...')
    questions = []
    # Shuffle the data to ensure randomness
    data = data.sample(frac=1).reset_index(drop=True)
    print('After Shuffling data...')
    for i in range(num_questions):
        # Select a random row from the shuffled data
        selected_row = data.iloc[i]
        correct_img_path = selected_row['img_path']
        ground_truth = selected_row['ground_truth']
        img_size = selected_row['img_size']
        
        # Randomly select three incorrect image paths
        incorrect_rows = [row for i, row in data.iterrows() if row['img_path'] != correct_img_path]
        # shuffle the incorrect list
        incorrect_choices = random.shuffle(incorrect_rows)
        print('we get the incorrect choices', incorrect_choices)
        # Create a list of options including the correct and incorrect image paths
        options = [correct_img_path]
        options.extend([row['img_path'] for row in incorrect_choices])
        
        # Shuffle the options to randomize their order
        options = random.sample(options, len(options))
        
        # Create a dictionary for the question
        question = {
            'question': f"What is the image path for {ground_truth} of size {img_size}?",
            'correct_answer': correct_img_path,
            'options': options
        }
        questions.append(question)
    
    print(questions)
    return questions

generate_questions(df,3)

# %%
# from flask import Flask, render_template, request
import pandas as pd
import random

df = pd.read_csv(r'D:\Projects\Face_analysis_game\code\notebook\web_app\v3.1_quiz\static\test.csv')
# return df

def generate_questions(data, num_questions):
    # print('Generating questions...')
    questions = []
    # Shuffle the data to ensure randomness
    data = data.sample(frac=1).reset_index(drop=True)
    # print('After Shuffling data...')
    for i in range(num_questions):
        # Select a random row from the shuffled data
        selected_row = data.iloc[i]
        correct_img_path = selected_row['img_path']
        ground_truth = selected_row['ground_truth']
        img_size = selected_row['img_size']
        
        # Randomly select three incorrect image paths
        incorrect_rows = [row for i, row in data.iterrows() if row['img_path'] != correct_img_path]
        # shuffle the incorrect list
        random.shuffle(incorrect_rows)
        incorrect_choices = incorrect_rows.copy()
        # print('we get the incorrect choices', incorrect_choices)
        # Create a list of options including the correct and incorrect image paths
        options = [correct_img_path]
        options.extend([row['img_path'] for row in incorrect_choices])
        
        # Shuffle the options to randomize their order
        options = random.sample(options, len(options))
        
        # Create a dictionary for the question
        question = {
            'question': f"What is the image path for {ground_truth} of size {img_size}?",
            'correct_answer': correct_img_path,
            'options': options
        }
        questions.append(question)
    
    # print(questions)
    return questions

generate_questions(df,3)
# Out:
# Generating questions...
# After Shuffling data...
# we get the incorrect choices [img_path        /path/to/image9.jpg
# ground_truth               building
# img_size                   1024x768
# Name: 8, dtype: object, img_path        /path/to/image4.jpg
# ground_truth                   tree
# img_size                  1600x1200
# Name: 7, dtype: object, img_path        /path/to/image6.jpg
# ground_truth                 sunset
# img_size                  1920x1080
# Name: 2, dtype: object, img_path        /path/to/image10.jpg
# ground_truth                    bird
# img_size                     800x600
# Name: 6, dtype: object, img_path        /path/to/image1.jpg
# ground_truth                    cat
# img_size                   1024x768
# Name: 4, dtype: object, img_path        /path/to/image8.jpg
# ground_truth               mountain
# img_size                  2000x1500
# Name: 9, dtype: object, img_path        /path/to/image5.jpg
# ground_truth                    car
# img_size                   1280x720
# Name: 1, dtype: object, img_path        /path/to/image3.jpg
# ground_truth                 flower
# img_size                   1200x900
# Name: 3, dtype: object, img_path        /path/to/image7.jpg
# ground_truth                  beach
# img_size                   1440x900
# Name: 5, dtype: object]
# we get the incorrect choices [img_path        /path/to/image3.jpg
# ground_truth                 flower
# img_size                   1200x900
# Name: 3, dtype: object, img_path        /path/to/image4.jpg
# ground_truth                   tree
# img_size                  1600x1200
# Name: 7, dtype: object, img_path        /path/to/image2.jpg
# ground_truth                    dog
# img_size                    800x600
# Name: 0, dtype: object, img_path        /path/to/image9.jpg
# ground_truth               building
# img_size                   1024x768
# Name: 8, dtype: object, img_path        /path/to/image8.jpg
# ground_truth               mountain
# img_size                  2000x1500
# Name: 9, dtype: object, img_path        /path/to/image7.jpg
# ground_truth                  beach
# img_size                   1440x900
# Name: 5, dtype: object, img_path        /path/to/image10.jpg
# ground_truth                    bird
# img_size                     800x600
# Name: 6, dtype: object, img_path        /path/to/image1.jpg
# ground_truth                    cat
# img_size                   1024x768
# Name: 4, dtype: object, img_path        /path/to/image6.jpg
# ground_truth                 sunset
# img_size                  1920x1080
# Name: 2, dtype: object]
# we get the incorrect choices [img_path        /path/to/image9.jpg
# ground_truth               building
# img_size                   1024x768
# Name: 8, dtype: object, img_path        /path/to/image2.jpg
# ground_truth                    dog
# img_size                    800x600
# Name: 0, dtype: object, img_path        /path/to/image7.jpg
# ground_truth                  beach
# img_size                   1440x900
# Name: 5, dtype: object, img_path        /path/to/image10.jpg
# ground_truth                    bird
# img_size                     800x600
# Name: 6, dtype: object, img_path        /path/to/image5.jpg
# ground_truth                    car
# img_size                   1280x720
# Name: 1, dtype: object, img_path        /path/to/image8.jpg
# ground_truth               mountain
# img_size                  2000x1500
# Name: 9, dtype: object, img_path        /path/to/image4.jpg
# ground_truth                   tree
# img_size                  1600x1200
# Name: 7, dtype: object, img_path        /path/to/image1.jpg
# ground_truth                    cat
# img_size                   1024x768
# Name: 4, dtype: object, img_path        /path/to/image3.jpg
# ground_truth                 flower
# img_size                   1200x900
# Name: 3, dtype: object]
# [{'question': 'What is the image path for dog of size 800x600?', 'correct_answer': '/path/to/image2.jpg', 'options': ['/path/to/image2.jpg', '/path/to/image6.jpg', '/path/to/image5.jpg', '/path/to/image8.jpg', '/path/to/image1.jpg', '/path/to/image3.jpg', '/path/to/image4.jpg', '/path/to/image9.jpg', '/path/to/image10.jpg', '/path/to/image7.jpg']}, {'question': 'What is the image path for car of size 1280x720?', 'correct_answer': '/path/to/image5.jpg', 'options': ['/path/to/image5.jpg', '/path/to/image1.jpg', '/path/to/image9.jpg', '/path/to/image6.jpg', '/path/to/image7.jpg', '/path/to/image4.jpg', '/path/to/image10.jpg', '/path/to/image2.jpg', '/path/to/image3.jpg', '/path/to/image8.jpg']}, {'question': 'What is the image path for sunset of size 1920x1080?', 'correct_answer': '/path/to/image6.jpg', 'options': ['/path/to/image2.jpg', '/path/to/image4.jpg', '/path/to/image7.jpg', '/path/to/image3.jpg', '/path/to/image5.jpg', '/path/to/image1.jpg', '/path/to/image6.jpg', '/path/to/image8.jpg', '/path/to/image9.jpg', '/path/to/image10.jpg']}]
# [{'question': 'What is the image path for dog of size 800x600?',
#   'correct_answer': '/path/to/image2.jpg',
#   'options': ['/path/to/image2.jpg',
#    '/path/to/image6.jpg',
#    '/path/to/image5.jpg',
#    '/path/to/image8.jpg',
#    '/path/to/image1.jpg',
#    '/path/to/image3.jpg',
#    '/path/to/image4.jpg',
#    '/path/to/image9.jpg',
#    '/path/to/image10.jpg',
#    '/path/to/image7.jpg']},
#  {'question': 'What is the image path for car of size 1280x720?',
#   'correct_answer': '/path/to/image5.jpg',
#   'options': ['/path/to/image5.jpg',
#    '/path/to/image1.jpg',
#    '/path/to/image9.jpg',
#    '/path/to/image6.jpg',
#    '/path/to/image7.jpg',
#    '/path/to/image4.jpg',
#    '/path/to/image10.jpg',
#    '/path/to/image2.jpg',
#    '/path/to/image3.jpg',
#    '/path/to/image8.jpg']},
#  {'question': 'What is the image path for sunset of size 1920x1080?',
#   'correct_answer': '/path/to/image6.jpg',
#   'options': ['/path/to/image2.jpg',
#    '/path/to/image4.jpg',
#    '/path/to/image7.jpg',
#    '/path/to/image3.jpg',
#    '/path/to/image5.jpg',
#    '/path/to/image1.jpg',
#    '/path/to/image6.jpg',
#    '/path/to/image8.jpg',
#    '/path/to/image9.jpg',
#    '/path/to/image10.jpg']}]
